# %%
# %pip install pandas matplotlib seaborn

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("./Applicant-details.csv")
df.sample(5)
# Out:
#        Applicant_ID  Annual_Income  Applicant_Age  Work_Experience  \
# 68169         72575        6443274             79               12
# 32388         37654        1743615             21                1
# 8603          48175        6679057             21                5
# 57741         79106        3612614             62               15
# 21647         53677        7091843             60               20
#
#       Marital_Status House_Ownership Vehicle_Ownership(car)  \
# 68169         single          rented                     no
# 32388         single          rented                    yes
# 8603          single          rented                    yes
# 57741         single          rented                     no
# 21647         single          rented                     no
#
#                  Occupation Residence_City Residence_State  \
# 68169  Chartered_Accountant      Thanjavur      Tamil_Nadu
# 32388               Dentist     Kumbakonam      Tamil_Nadu
# ...

# %%
# df["Annual_Income"].plot(kind="box")
sns.boxplot(df["Annual_Income"]) # type: ignore
# Out:
# <Axes: ylabel='Annual_Income'>

# %%
# df["Years_in_Current_Employment"].plot(kind="")
sns.displot(df["Years_in_Current_Employment"]) # type: ignore

# %%
df["Occupation"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='Occupation'>

# %%
df["Residence_State"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Residence_State'>

# %%
df["Residence_City"].value_counts().plot()
# Out:
# <Axes: xlabel='Residence_City'>

# %%
df["Vehicle_Ownership(car)"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Vehicle_Ownership(car)'>

# %%
# sns.countplot(df.Marital_Status) # type: ignore
df["House_Ownership"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='House_Ownership'>
